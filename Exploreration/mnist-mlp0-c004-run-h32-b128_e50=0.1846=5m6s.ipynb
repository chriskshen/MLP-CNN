# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/train-images.idx3-ubyte
# /kaggle/input/t10k-labels.idx1-ubyte
# /kaggle/input/t10k-images.idx3-ubyte
# /kaggle/input/train-labels.idx1-ubyte
# /kaggle/input/t10k-labels-idx1-ubyte/t10k-labels-idx1-ubyte
# /kaggle/input/t10k-images-idx3-ubyte/t10k-images-idx3-ubyte
# /kaggle/input/train-labels-idx1-ubyte/train-labels-idx1-ubyte
# /kaggle/input/train-images-idx3-ubyte/train-images-idx3-ubyte

# %%
train_images_path = '/kaggle/input/train-images-idx3-ubyte/train-images-idx3-ubyte'
train_labels_path = '/kaggle/input/train-labels-idx1-ubyte/train-labels-idx1-ubyte'
test_images_path = '/kaggle/input/t10k-images-idx3-ubyte/t10k-images-idx3-ubyte'
test_labels_path = '/kaggle/input/t10k-labels-idx1-ubyte/t10k-labels-idx1-ubyte'

# %%
import keras
import tensorflow as tf
import time
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Add, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# %%
import numpy as np
import struct

def load_mnist_images(filename):
    with open(filename, 'rb') as f:
        magic, num, rows, cols = struct.unpack('>IIII', f.read(16))
        images = np.fromfile(f, dtype=np.uint8).reshape(num, rows, cols)
        return images / 255.0  # Normalize pixel values to [0, 1]

def load_mnist_labels(filename):
    with open(filename, 'rb') as f:
        magic, num = struct.unpack('>II', f.read(8))
        labels = np.fromfile(f, dtype=np.uint8)
        return labels

# Load training and testing data
X_train = load_mnist_images(train_images_path)
y_train = load_mnist_labels(train_labels_path)
X_test = load_mnist_images(test_images_path)
y_test = load_mnist_labels(test_labels_path)

# %%
print(f"x_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"x_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# x_train: (60000, 28, 28)
# y_train: (60000,)
# x_test: (10000, 28, 28)
# y_test: (10000,)

# %%
X_train = X_train.astype('float32')  / 255.0
X_test = X_test.astype('float32')  / 255.0

# %% [markdown]
# # Create the MLP+CNN Model

# %%
X_train = X_train.reshape(-1,28,28,1)
X_test  = X_test.reshape(-1,28,28,1)

print("x_train : ",X_train.shape)
print("y_train : ",y_train.shape)
print("x_test  : ",X_test.shape)
print("y_test  : ",y_test.shape)
# Out:
# x_train :  (60000, 28, 28, 1)
# y_train :  (60000,)
# x_test  :  (10000, 28, 28, 1)
# y_test  :  (10000,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout

# Define the model
model0 = Sequential()

# Convolutional Layer
model0.add(Conv2D(filters=4, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))

# Flatten the output from the convolutional layer
model0.add(Flatten())

# Fully connected layer
model0.add(Dense(32, activation='relu'))
model0.add(Dropout(0.3))

# Output layer
model0.add(Dense(10, activation='softmax'))

# Compile the model
model0.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Summary
model0.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 4)      │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2704)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │        86,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 86,930 (339.57 KB)
#  Trainable params: 86,930 (339.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

import os

if os.path.exists("Best_points.keras"):
    os.remove("Best_points.keras")

MCP = ModelCheckpoint('Best_points.keras', verbose=1, save_best_only=True, monitor='val_accuracy', mode='max')

# %%
batch_size  = 128
epochs      = 50

start_time0 = time.time()
history0 = model0.fit(  X_train, y_train,
                      batch_size      = batch_size,
                      epochs          = epochs,
                      
                      validation_data = (X_test, y_test),callbacks=MCP)
stop_time0 = time.time()

# Calculate elapsed time
elapsed_time0 = stop_time0 - start_time0
minutes0 = int(elapsed_time0 // 60)
seconds0 = int(elapsed_time0 % 60)

# Print time used in minutes and seconds
print(f'training_time0 = {minutes0} min {seconds0} sec')
# Out:
# Epoch 1/50
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1083 - loss: 2.3021
# Epoch 1: val_accuracy improved from -inf to 0.11350, saving model to Best_points.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.1083 - loss: 2.3021 - val_accuracy: 0.1135 - val_loss: 2.3013
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1121 - loss: 2.3013
# Epoch 2: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1121 - loss: 2.3013 - val_accuracy: 0.1135 - val_loss: 2.3010
# Epoch 3/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1125 - loss: 2.3012
# Epoch 3: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.1125 - loss: 2.3012 - val_accuracy: 0.1135 - val_loss: 2.3009
# Epoch 4/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1125 - loss: 2.3012
# Epoch 4: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.1125 - loss: 2.3012 - val_accuracy: 0.1135 - val_loss: 2.3008
# Epoch 5/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1141 - loss: 2.3008
# Epoch 5: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1141 - loss: 2.3008 - val_accuracy: 0.1135 - val_loss: 2.3008
# Epoch 6/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1118 - loss: 2.3009
# Epoch 6: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1118 - loss: 2.3009 - val_accuracy: 0.1135 - val_loss: 2.3007
# Epoch 7/50
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1142 - loss: 2.3003
# Epoch 7: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1142 - loss: 2.3003 - val_accuracy: 0.1135 - val_loss: 2.3007
# Epoch 8/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.
val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1137 - loss: 2.2957 - val_accuracy: 0.1135 - val_loss: 2.2951
# Epoch 34/50
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1118 - loss: 2.2957
# Epoch 34: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1119 - loss: 2.2957 - val_accuracy: 0.1135 - val_loss: 2.2946
# Epoch 35/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1107 - loss: 2.2952
# Epoch 35: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.1107 - loss: 2.2952 - val_accuracy: 0.1135 - val_loss: 2.2940
# Epoch 36/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1111 - loss: 2.2941
# Epoch 36: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.1111 - loss: 2.2941 - val_accuracy: 0.1135 - val_loss: 2.2933
# Epoch 37/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1133 - loss: 2.2935
# Epoch 37: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1133 - loss: 2.2935 - val_accuracy: 0.1135 - val_loss: 2.2926
# Epoch 38/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1139 - loss: 2.2925
# Epoch 38: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1139 - loss: 2.2925 - val_accuracy: 0.1135 - val_loss: 2.2917
# Epoch 39/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1116 - loss: 2.2921
# Epoch 39: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.1116 - loss: 2.2921 - val_accuracy: 0.1135 - val_loss: 2.2911
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1117 - loss: 2.2911
# Epoch 40: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.1117 - loss: 2.2911 - val_accuracy: 0.1135 - val_loss: 2.2897
# Epoch 41/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1127 - loss: 2.2904
# Epoch 41: val_accuracy did not improve from 0.11350
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.1127 - loss: 2.2904 - val_accuracy: 0.1135 - val_loss: 2.2885
# Epoch 42/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1156 - loss: 2.2888
# Epoch 42: val_accuracy improved from 0.11350 to 0.11440, saving model to Best_points.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1156 - loss: 2.2888 - val_accuracy: 0.1144 - val_loss: 2.2872
# Epoch 43/50
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1270 - loss: 2.2867
# Epoch 43: val_accuracy did not improve from 0.11440
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.1270 - loss: 2.2867 - val_accuracy: 0.1135 - val_loss: 2.2856
# Epoch 44/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1232 - loss: 2.2860
# Epoch 44: val_accuracy improved from 0.11440 to 0.11490, saving model to Best_points.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.1232 - loss: 2.2860 - val_accuracy: 0.1149 - val_loss: 2.2838
# Epoch 45/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1341 - loss: 2.2842
# Epoch 45: val_accuracy did not improve from 0.11490
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1341 - loss: 2.2842 - val_accuracy: 0.1141 - val_loss: 2.2819
# Epoch 46/50
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1261 - loss: 2.2827
# Epoch 46: val_accuracy improved from 0.11490 to 0.13590, saving model to Best_points.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.1261 - loss: 2.2827 - val_accuracy: 0.1359 - val_loss: 2.2796
# Epoch 47/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1463 - loss: 2.2792
# Epoch 47: val_accuracy improved from 0.13590 to 0.14680, saving model to Best_points.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1463 - loss: 2.2792 - val_accuracy: 0.1468 - val_loss: 2.2771
# Epoch 48/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1466 - loss: 2.2769
# Epoch 48: val_accuracy improved from 0.14680 to 0.15520, saving model to Best_points.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.1466 - loss: 2.2769 - val_accuracy: 0.1552 - val_loss: 2.2738
# Epoch 49/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1684 - loss: 2.2741
# Epoch 49: val_accuracy did not improve from 0.15520
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1684 - loss: 2.2741 - val_accuracy: 0.1304 - val_loss: 2.2704
# Epoch 50/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1838 - loss: 2.2701
# Epoch 50: val_accuracy improved from 0.15520 to 0.18460, saving model to Best_points.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.1838 - loss: 2.2701 - val_accuracy: 0.1846 - val_loss: 2.2661
# training_time0 = 5 min 6 sec

# %%
from tensorflow.keras.models import load_model

# Load the best saved model
best_model = load_model('Best_points.keras')

# Evaluate the model on the test dataset
score = best_model.evaluate(X_test, y_test, verbose=0)

# Print the evaluation results
print(f'Test loss     : {score[0]:4.4f}')
print(f'Test accuracy : {score[1]:4.4f}')
# Out:
# Test loss     : 2.2661
# Test accuracy : 0.1846

# %%
plt.plot(history0.history['loss'], label='train')
plt.plot(history0.history['val_loss'], label='test')
plt.legend()

# %%
plt.plot(history0.history['accuracy'], label='train')
plt.plot(history0.history['val_accuracy'], label='test')
plt.legend()
