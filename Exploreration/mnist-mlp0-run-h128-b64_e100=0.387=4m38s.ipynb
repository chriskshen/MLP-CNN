# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/train-images.idx3-ubyte
# /kaggle/input/t10k-labels.idx1-ubyte
# /kaggle/input/t10k-images.idx3-ubyte
# /kaggle/input/train-labels.idx1-ubyte
# /kaggle/input/t10k-labels-idx1-ubyte/t10k-labels-idx1-ubyte
# /kaggle/input/t10k-images-idx3-ubyte/t10k-images-idx3-ubyte
# /kaggle/input/train-labels-idx1-ubyte/train-labels-idx1-ubyte
# /kaggle/input/train-images-idx3-ubyte/train-images-idx3-ubyte

# %%
train_images_path = '/kaggle/input/train-images-idx3-ubyte/train-images-idx3-ubyte'
train_labels_path = '/kaggle/input/train-labels-idx1-ubyte/train-labels-idx1-ubyte'
test_images_path = '/kaggle/input/t10k-images-idx3-ubyte/t10k-images-idx3-ubyte'
test_labels_path = '/kaggle/input/t10k-labels-idx1-ubyte/t10k-labels-idx1-ubyte'

# %%
import keras
import tensorflow as tf
import time
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Add, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# %%
import numpy as np
import struct

def load_mnist_images(filename):
    with open(filename, 'rb') as f:
        magic, num, rows, cols = struct.unpack('>IIII', f.read(16))
        images = np.fromfile(f, dtype=np.uint8).reshape(num, rows, cols)
        return images / 255.0  # Normalize pixel values to [0, 1]

def load_mnist_labels(filename):
    with open(filename, 'rb') as f:
        magic, num = struct.unpack('>II', f.read(8))
        labels = np.fromfile(f, dtype=np.uint8)
        return labels

# Load training and testing data
X_train = load_mnist_images(train_images_path)
y_train = load_mnist_labels(train_labels_path)
X_test = load_mnist_images(test_images_path)
y_test = load_mnist_labels(test_labels_path)

# %%
print(f"x_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"x_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# x_train: (60000, 28, 28)
# y_train: (60000,)
# x_test: (10000, 28, 28)
# y_test: (10000,)

# %%
X_train = X_train.astype('float32')  / 255.0
X_test = X_test.astype('float32')  / 255.0

# %% [markdown]
# # Create the MLP Model

# %%
# Flatten the images from 28x28 dimensions and normalize them
X_train = X_train.reshape((X_train.shape[0], 28 * 28))
X_test = X_test.reshape((X_test.shape[0], 28 * 28))

print("x_train : ",X_train.shape)
print("y_train : ",y_train.shape)
print("x_test  : ",X_test.shape)
print("y_test  : ",y_test.shape)
# Out:
# x_train :  (60000, 784)
# y_train :  (60000,)
# x_test  :  (10000, 784)
# y_test  :  (10000,)

# %%
# Define the model
model0 = Sequential()

# Input layer
# Define the input layer with the shape corresponding to flattened 28x28 images
model0.add(tf.keras.layers.Input(shape=(28 * 28,)))

# Add the hidden layer with 128 units and ReLU activation function
model0.add(tf.keras.layers.Dense(128, activation='relu'))

# Add a dropout layer with a rate of 0.3 to reduce overfitting during training
model0.add(tf.keras.layers.Dropout(0.3))

# Output layer: Using softmax activation for multi-class classification.
model0.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
# Summary of the model
model0.summary()

model0.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

import os

if os.path.exists("Best_points.keras"):
    os.remove("Best_points.keras")

MCP = ModelCheckpoint('Best_points.keras', verbose=1, save_best_only=True, monitor='val_accuracy', mode='max')

# %%
batch_size  = 64
epochs      = 100

start_time0 = time.time()
history0 = model0.fit(  X_train, y_train,
                      batch_size      = batch_size,
                      epochs          = epochs,
                      
                      validation_data = (X_test, y_test),callbacks=MCP)
stop_time0 = time.time()

# Calculate elapsed time
elapsed_time0 = stop_time0 - start_time0
minutes0 = int(elapsed_time0 // 60)
seconds0 = int(elapsed_time0 % 60)

# Print time used in minutes and seconds
print(f'training_time0 = {minutes0} min {seconds0} sec')
# Out:
# Epoch 1/100
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1268 - loss: 2.3008
# Epoch 1: val_accuracy improved from -inf to 0.11350, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1267 - loss: 2.3008 - val_accuracy: 0.1135 - val_loss: 2.2995
# Epoch 2/100
# 926/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1133 - loss: 2.2994
# Epoch 2: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1133 - loss: 2.2994 - val_accuracy: 0.1135 - val_loss: 2.2992
# Epoch 3/100
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1117 - loss: 2.2994
# Epoch 3: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1117 - loss: 2.2994 - val_accuracy: 0.1135 - val_loss: 2.2989
# Epoch 4/100
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1134 - loss: 2.2990
# Epoch 4: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1134 - loss: 2.2990 - val_accuracy: 0.1135 - val_loss: 2.2987
# Epoch 5/100
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1128 - loss: 2.2989
# Epoch 5: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1128 - loss: 2.2989 - val_accuracy: 0.1135 - val_loss: 2.2985
# Epoch 6/100
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1101 - loss: 2.2990
# Epoch 6: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1101 - loss: 2.2990 - val_accuracy: 0.1135 - val_loss: 2.2983
# Epoch 7/100
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1145 - loss: 2.2984
# Epoch 7: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1145 - loss: 2.2984 - val_accuracy: 0.1135 - val_loss: 2.2980
# Epoch 8/100
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1098 - loss: 2.2981
# Epoch 8: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1098 - loss: 2.2981 - val_accuracy: 0.1135 - val_loss: 2.2977
# Epoch 9/100
# 924/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1102 - loss: 2.2984
# Epoch 9: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1103 - loss: 2.2984 - val_accuracy: 0.1135 - val_loss: 2.2975
# Epoch 10/100
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1135 - loss: 2.2976
# Epoch 10: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1135 - loss: 2.2976 - val_accuracy: 0.1135 - val_loss: 2.2973
# Epoch 11/100
# 922/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1126 - loss: 2.2975
# Epoch 11: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1126 - loss: 2.2975 - val_accuracy: 0.1135 - val_loss: 2.2971
# Epoch 12/100
# 930/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1123 - loss: 2.2972
# Epoch 12: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1123 - loss: 2.2972 - val_accuracy: 0.1135 - val_loss: 2.2968
# Epoch 13/100
# 919/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1099 - loss: 2.2974
# Epoch 13: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1100 - loss: 2.2974 - val_accuracy: 0.1135 - val_loss: 2.2965
# Epoch 14/100
# 924/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1120 - loss: 2.2964
# Epoch 14: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1120 - loss: 2.2964 - val_accuracy: 0.1135 - val_loss: 2.2962
# Epoch 15/100
# 919/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1151 - loss: 2.2960
# Epoch 15: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1151 - loss: 2.2960 - val_accuracy: 0.1135 - val_loss: 2.2960
# Epoch 16/100
# 936/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1131 - loss: 2.2960
# Epoch 16: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1131 - loss: 2.2960 - val_accuracy: 0.1135 - val_loss: 2.2956
# Epoch 17/100
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1120 - loss: 2.2959
# Epoch 17: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1120 - loss: 2.2959 - val_accuracy: 0.1135 - val_loss: 2.2953
# Epoch 18/100
# 930/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1146 - loss: 2.2953
# Epoch 18: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1146 - loss: 2.2953 - val_accuracy: 0.1135 - val_loss: 2.2951
# Epoch 19/100
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1132 - loss: 2.2952
# Epoch 19: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1132 - loss: 2.2952 - val_accuracy: 0.1135 - val_loss: 2.2948
# Epoch 20/100
# 929/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1090 - loss: 2.2952
# Epoch 20: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1091 - loss: 2.2952 - val_accuracy: 0.1135 - val_loss: 2.2945
# Epoch 21/100
# 922/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1144 - loss: 2.2945
# Epoch 21: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1144 - loss: 2.2945 - val_accuracy: 0.1135 - val_loss: 2.2941
# Epoch 22/100
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1102 - loss: 2.2947
# Epoch 22: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1102 - loss: 2.2947 - val_accuracy: 0.1135 - val_loss: 2.2938
# Epoch 23/100
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1110 - loss: 2.2942
# Epoch 23: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1110 - loss: 2.2942 - val_accuracy: 0.1135 - val_loss: 2.2934
# Epoch 24/100
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1117 - loss: 2.2937
# Epoch 24: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1118 - loss: 2.2937 - val_accuracy: 0.1135 - val_loss: 2.2931
# Epoch 25/100
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1119 - loss: 2.2935
# Epoch 25: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1119 - loss: 2.2935 - val_accuracy: 0.1135 - val_loss: 2.2928
# Epoch 26/100
# 921/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1111 - loss: 2.2931
# Epoch 26: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1111 - loss: 2.2931 - val_accuracy: 0.1135 - val_loss: 2.2923
# Epoch 27/100
# 922/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1114 - loss: 2.2927
# Epoch 27: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1114 - loss: 2.2927 - val_accuracy: 0.1135 - val_loss: 2.2920
# Epoch 28/100
# 923/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1105 - loss: 2.2921
# Epoch 28: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1105 - loss: 2.2921 - val_accuracy: 0.1135 - val_loss: 2.2915
# Epoch 29/100
# 923/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1138 - loss: 2.2920
# Epoch 29: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1137 - loss: 2.2920 - val_accuracy: 0.1135 - val_loss: 2.2912
# Epoch 30/100
# 926/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1200 - loss: 2.2912
# Epoch 30: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1200 - loss: 2.2912 - val_accuracy: 0.1135 - val_loss: 2.2907
# Epoch 31/100
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1126 - loss: 2.2909
# Epoch 31: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1126 - loss: 2.2909 - val_accuracy: 0.1135 - val_loss: 2.2904
# Epoch 32/100
# 924/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1128 - loss: 2.2907
# Epoch 32: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1128 - loss: 2.2907 - val_accuracy: 0.1135 - val_loss: 2.2899
# Epoch 33/100
# 931/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1136 - loss: 2.2899
# Epoch 33: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1136 - loss: 2.2899 - val_accuracy: 0.1135 - val_loss: 2.2896
# Epoch 34/100
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1141 - loss: 2.2897
# Epoch 34: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1141 - loss: 2.2897 - val_accuracy: 0.1135 - val_loss: 2.2890
# Epoch 35/100
# 924/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1155 - loss: 2.2892
# Epoch 35: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1155 - loss: 2.2892 - val_accuracy: 0.1135 - val_loss: 2.2885
# Epoch 36/100
# 919/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1139 - loss: 2.2890
# Epoch 36: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1139 - loss: 2.2890 - val_accuracy: 0.1135 - val_loss: 2.2880
# Epoch 37/100
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1119 - loss: 2.2887
# Epoch 37: val_accuracy improved from 0.11350 to 0.11360, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1119 - loss: 2.2887 - val_accuracy: 0.1136 - val_loss: 2.2875
# Epoch 38/100
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1214 - loss: 2.2878
# Epoch 38: val_accuracy did not improve from 0.11360
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1214 - loss: 2.2878 - val_accuracy: 0.1135 - val_loss: 2.2869
# Epoch 39/100
# 936/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1153 - loss: 2.2870
# Epoch 39: val_accuracy did not improve from 0.11360
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1153 - loss: 2.2870 - val_accuracy: 0.1136 - val_loss: 2.2864
# Epoch 40/100
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1173 - loss: 2.2868
# Epoch 40: val_accuracy did not improve from 0.11360
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1173 - loss: 2.2868 - val_accuracy: 0.1135 - val_loss: 2.2859
# Epoch 41/100
# 926/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1148 - loss: 2.2862
# Epoch 41: val_accuracy did not improve from 0.11360
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1148 - loss: 2.2862 - val_accuracy: 0.1135 - val_loss: 2.2854
# Epoch 42/100
# 922/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1163 - loss: 2.2855
# Epoch 42: val_accuracy improved from 0.11360 to 0.11370, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1163 - loss: 2.2855 - val_accuracy: 0.1137 - val_loss: 2.2847
# Epoch 43/100
# 928/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1167 - loss: 2.2851
# Epoch 43: val_accuracy improved from 0.11370 to 0.11820, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1167 - loss: 2.2851 - val_accuracy: 0.1182 - val_loss: 2.2840
# Epoch 44/100
# 931/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1237 - loss: 2.2847
# Epoch 44: val_accuracy improved from 0.11820 to 0.12670, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1237 - loss: 2.2847 - val_accuracy: 0.1267 - val_loss: 2.2835
# Epoch 45/100
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1323 - loss: 2.2838
# Epoch 45: val_accuracy did not improve from 0.12670
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1322 - loss: 2.2838 - val_accuracy: 0.1135 - val_loss: 2.2828
# Epoch 46/100
# 936/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1192 - loss: 2.2836
# Epoch 46: val_accuracy did not improve from 0.12670
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1192 - loss: 2.2836 - val_accuracy: 0.1135 - val_loss: 2.2821
# Epoch 47/100
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1248 - loss: 2.2826
# Epoch 47: val_accuracy did not improve from 0.12670
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1248 - loss: 2.2826 - val_accuracy: 0.1135 - val_loss: 2.2813
# Epoch 48/100
# 921/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1205 - loss: 2.2819
# Epoch 48: val_accuracy improved from 0.12670 to 0.15390, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1206 - loss: 2.2819 - val_accuracy: 0.1539 - val_loss: 2.2807
# Epoch 49/100
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1503 - loss: 2.2810
# Epoch 49: val_accuracy did not improve from 0.15390
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1502 - loss: 2.2810 - val_accuracy: 0.1153 - val_loss: 2.2799
# Epoch 50/100
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1460 - loss: 2.2808
# Epoch 50: val_accuracy did not improve from 0.15390
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1460 - loss: 2.2808 - val_accuracy: 0.1153 - val_loss: 2.2792
# Epoch 51/100
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1284 - loss: 2.2794
# Epoch 51: val_accuracy did not improve from 0.15390
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1285 - loss: 2.2794 - val_accuracy: 0.1220 - val_loss: 2.2783
# Epoch 52/100
# 926/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1432 - loss: 2.2793
# Epoch 52: val_accuracy did not improve from 0.15390
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1433 - loss: 2.2793 - val_accuracy: 0.1141 - val_loss: 2.2774
# Epoch 53/100
# 923/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1270 - loss: 2.2779
# Epoch 53: val_accuracy did not improve from 0.15390
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1272 - loss: 2.2779 - val_accuracy: 0.1457 - val_loss: 2.2765
# Epoch 54/100
# 926/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1597 - loss: 2.2767
# Epoch 54: val_accuracy did not improve from 0.15390
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1595 - loss: 2.2767 - val_accuracy: 0.1428 - val_loss: 2.2757
# Epoch 55/100
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1526 - loss: 2.2760
# Epoch 55: val_accuracy improved from 0.15390 to 0.15620, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1526 - loss: 2.2760 - val_accuracy: 0.1562 - val_loss: 2.2748
# Epoch 56/100
# 930/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1516 - loss: 2.2755
# Epoch 56: val_accuracy did not improve from 0.15620
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1517 - loss: 2.2755 - val_accuracy: 0.1516 - val_loss: 2.2738
# Epoch 57/100
# 922/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1559 - loss: 2.2739
# Epoch 57: val_accuracy improved from 0.15620 to 0.17340, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1560 - loss: 2.2739 - val_accuracy: 0.1734 - val_loss: 2.2729
# Epoch 58/100
# 921/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1679 - loss: 2.2736
# Epoch 58: val_accuracy improved from 0.17340 to 0.19040, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1679 - loss: 2.2736 - val_accuracy: 0.1904 - val_loss: 2.2718
# Epoch 59/100
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1734 - loss: 2.2729
# Epoch 59: val_accuracy did not improve from 0.19040
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1733 - loss: 2.2729 - val_accuracy: 0.1634 - val_loss: 2.2709
# Epoch 60/100
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1767 - loss: 2.2711
# Epoch 60: val_accuracy did not improve from 0.19040
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1767 - loss: 2.2711 - val_accuracy: 0.1477 - val_loss: 2.2697
# Epoch 61/100
# 921/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1642 - loss: 2.2700
# Epoch 61: val_accuracy improved from 0.19040 to 0.21200, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1645 - loss: 2.2700 - val_accuracy: 0.2120 - val_loss: 2.2685
# Epoch 62/100
# 928/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2018 - loss: 2.2691
# Epoch 62: val_accuracy did not improve from 0.21200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2018 - loss: 2.2691 - val_accuracy: 0.1265 - val_loss: 2.2675
# Epoch 63/100
# 920/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1777 - loss: 2.2679
# Epoch 63: val_accuracy did not improve from 0.21200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1780 - loss: 2.2679 - val_accuracy: 0.1801 - val_loss: 2.2662
# Epoch 64/100
# 920/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1995 - loss: 2.2673
# Epoch 64: val_accuracy improved from 0.21200 to 0.21880, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1995 - loss: 2.2673 - val_accuracy: 0.2188 - val_loss: 2.2650
# Epoch 65/100
# 936/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2175 - loss: 2.2660
# Epoch 65: val_accuracy did not improve from 0.21880
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2175 - loss: 2.2660 - val_accuracy: 0.1810 - val_loss: 2.2638
# Epoch 66/100
# 931/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2196 - loss: 2.2642
# Epoch 66: val_accuracy did not improve from 0.21880
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2195 - loss: 2.2642 - val_accuracy: 0.1852 - val_loss: 2.2624
# Epoch 67/100
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1909 - loss: 2.2629
# Epoch 67: val_accuracy improved from 0.21880 to 0.24840, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1909 - loss: 2.2629 - val_accuracy: 0.2484 - val_loss: 2.2611
# Epoch 68/100
# 929/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2337 - loss: 2.2619
# Epoch 68: val_accuracy did not improve from 0.24840
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2336 - loss: 2.2619 - val_accuracy: 0.2144 - val_loss: 2.2595
# Epoch 69/100
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2179 - loss: 2.2603
# Epoch 69: val_accuracy did not improve from 0.24840
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2180 - loss: 2.2603 - val_accuracy: 0.2375 - val_loss: 2.2580
# Epoch 70/100
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2172 - loss: 2.2583
# Epoch 70: val_accuracy improved from 0.24840 to 0.27110, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2172 - loss: 2.2583 - val_accuracy: 0.2711 - val_loss: 2.2566
# Epoch 71/100
# 924/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2446 - loss: 2.2570
# Epoch 71: val_accuracy did not improve from 0.27110
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2446 - loss: 2.2570 - val_accuracy: 0.2217 - val_loss: 2.2549
# Epoch 72/100
# 926/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2127 - loss: 2.2548
# Epoch 72: val_accuracy improved from 0.27110 to 0.28700, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2129 - loss: 2.2548 - val_accuracy: 0.2870 - val_loss: 2.2534
# Epoch 73/100
# 922/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2523 - loss: 2.2544
# Epoch 73: val_accuracy did not improve from 0.28700
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2522 - loss: 2.2544 - val_accuracy: 0.2421 - val_loss: 2.2515
# Epoch 74/100
# 920/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2451 - loss: 2.2523
# Epoch 74: val_accuracy improved from 0.28700 to 0.29340, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2452 - loss: 2.2523 - val_accuracy: 0.2934 - val_loss: 2.2499
# Epoch 75/100
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2684 - loss: 2.2511
# Epoch 75: val_accuracy did not improve from 0.29340
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2684 - loss: 2.2511 - val_accuracy: 0.2531 - val_loss: 2.2479
# Epoch 76/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2311 - loss: 2.2487
# Epoch 76: val_accuracy did not improve from 0.29340
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2311 - loss: 2.2487 - val_accuracy: 0.2886 - val_loss: 2.2462
# Epoch 77/100
# 922/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2735 - loss: 2.2476
# Epoch 77: val_accuracy improved from 0.29340 to 0.30090, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2733 - loss: 2.2476 - val_accuracy: 0.3009 - val_loss: 2.2443
# Epoch 78/100
# 921/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2778 - loss: 2.2456
# Epoch 78: val_accuracy did not improve from 0.30090
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2777 - loss: 2.2456 - val_accuracy: 0.2899 - val_loss: 2.2424
# Epoch 79/100
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2785 - loss: 2.2434
# Epoch 79: val_accuracy did not improve from 0.30090
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2785 - loss: 2.2434 - val_accuracy: 0.2559 - val_loss: 2.2402
# Epoch 80/100
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2567 - loss: 2.2409
# Epoch 80: val_accuracy improved from 0.30090 to 0.36200, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2567 - loss: 2.2409 - val_accuracy: 0.3620 - val_loss: 2.2383
# Epoch 81/100
# 936/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2902 - loss: 2.2384
# Epoch 81: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2902 - loss: 2.2384 - val_accuracy: 0.3427 - val_loss: 2.2358
# Epoch 82/100
# 924/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3125 - loss: 2.2374
# Epoch 82: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3123 - loss: 2.2374 - val_accuracy: 0.2479 - val_loss: 2.2336
# Epoch 83/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2695 - loss: 2.2353
# Epoch 83: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2695 - loss: 2.2353 - val_accuracy: 0.2990 - val_loss: 2.2312
# Epoch 84/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2865 - loss: 2.2324
# Epoch 84: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2865 - loss: 2.2324 - val_accuracy: 0.3314 - val_loss: 2.2291
# Epoch 85/100
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3091 - loss: 2.2306
# Epoch 85: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3090 - loss: 2.2306 - val_accuracy: 0.2941 - val_loss: 2.2262
# Epoch 86/100
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3056 - loss: 2.2272
# Epoch 86: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3056 - loss: 2.2272 - val_accuracy: 0.3427 - val_loss: 2.2237
# Epoch 87/100
# 927/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3243 - loss: 2.2258
# Epoch 87: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3242 - loss: 2.2257 - val_accuracy: 0.3005 - val_loss: 2.2209
# Epoch 88/100
# 929/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3091 - loss: 2.2218
# Epoch 88: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3090 - loss: 2.2218 - val_accuracy: 0.3293 - val_loss: 2.2181
# Epoch 89/100
# 928/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3211 - loss: 2.2202
# Epoch 89: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3211 - loss: 2.2202 - val_accuracy: 0.3260 - val_loss: 2.2155
# Epoch 90/100
# 928/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3092 - loss: 2.2166
# Epoch 90: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3093 - loss: 2.2166 - val_accuracy: 0.3417 - val_loss: 2.2125
# Epoch 91/100
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3374 - loss: 2.2138
# Epoch 91: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3373 - loss: 2.2138 - val_accuracy: 0.3526 - val_loss: 2.2094
# Epoch 92/100
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3296 - loss: 2.2113
# Epoch 92: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3297 - loss: 2.2113 - val_accuracy: 0.3166 - val_loss: 2.2061
# Epoch 93/100
# 930/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3216 - loss: 2.2077
# Epoch 93: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3216 - loss: 2.2077 - val_accuracy: 0.3549 - val_loss: 2.2030
# Epoch 94/100
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3360 - loss: 2.2046
# Epoch 94: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3360 - loss: 2.2046 - val_accuracy: 0.3504 - val_loss: 2.1997
# Epoch 95/100
# 921/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3450 - loss: 2.2010
# Epoch 95: val_accuracy did not improve from 0.36200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3448 - loss: 2.2010 - val_accuracy: 0.3548 - val_loss: 2.1961
# Epoch 96/100
# 923/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3351 - loss: 2.1975
# Epoch 96: val_accuracy improved from 0.36200 to 0.37340, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3352 - loss: 2.1975 - val_accuracy: 0.3734 - val_loss: 2.1926
# Epoch 97/100
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3398 - loss: 2.1945
# Epoch 97: val_accuracy improved from 0.37340 to 0.37560, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3398 - loss: 2.1945 - val_accuracy: 0.3756 - val_loss: 2.1889
# Epoch 98/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3425 - loss: 2.1912
# Epoch 98: val_accuracy did not improve from 0.37560
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3425 - loss: 2.1912 - val_accuracy: 0.3739 - val_loss: 2.1857
# Epoch 99/100
# 929/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3565 - loss: 2.1876
# Epoch 99: val_accuracy improved from 0.37560 to 0.38700, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3564 - loss: 2.1875 - val_accuracy: 0.3870 - val_loss: 2.1814
# Epoch 100/100
# 921/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3578 - loss: 2.1837
# Epoch 100: val_accuracy did not improve from 0.38700
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3577 - loss: 2.1836 - val_accuracy: 0.3750 - val_loss: 2.1774
# training_time0 = 4 min 38 sec

# %%
from tensorflow.keras.models import load_model

# Load the best saved model
best_model = load_model('Best_points.keras')

# Evaluate the model on the test dataset
score = best_model.evaluate(X_test, y_test, verbose=0)

# Print the evaluation results
print(f'Test loss     : {score[0]:4.4f}')
print(f'Test accuracy : {score[1]:4.4f}')
# Out:
# Test loss     : 2.1814
# Test accuracy : 0.3870

# %%
plt.plot(history0.history['loss'], label='train')
plt.plot(history0.history['val_loss'], label='test')
plt.legend()

# %%
plt.plot(history0.history['accuracy'], label='train')
plt.plot(history0.history['val_accuracy'], label='test')
plt.legend()
