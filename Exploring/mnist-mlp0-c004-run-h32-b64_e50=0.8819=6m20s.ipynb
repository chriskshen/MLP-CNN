# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/train-images.idx3-ubyte
# /kaggle/input/t10k-labels.idx1-ubyte
# /kaggle/input/t10k-images.idx3-ubyte
# /kaggle/input/train-labels.idx1-ubyte
# /kaggle/input/t10k-labels-idx1-ubyte/t10k-labels-idx1-ubyte
# /kaggle/input/t10k-images-idx3-ubyte/t10k-images-idx3-ubyte
# /kaggle/input/train-labels-idx1-ubyte/train-labels-idx1-ubyte
# /kaggle/input/train-images-idx3-ubyte/train-images-idx3-ubyte

# %%
train_images_path = '/kaggle/input/train-images-idx3-ubyte/train-images-idx3-ubyte'
train_labels_path = '/kaggle/input/train-labels-idx1-ubyte/train-labels-idx1-ubyte'
test_images_path = '/kaggle/input/t10k-images-idx3-ubyte/t10k-images-idx3-ubyte'
test_labels_path = '/kaggle/input/t10k-labels-idx1-ubyte/t10k-labels-idx1-ubyte'

# %%
import keras
import tensorflow as tf
import time
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Add, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# %%
import numpy as np
import struct

def load_mnist_images(filename):
    with open(filename, 'rb') as f:
        magic, num, rows, cols = struct.unpack('>IIII', f.read(16))
        images = np.fromfile(f, dtype=np.uint8).reshape(num, rows, cols)
        return images / 255.0  # Normalize pixel values to [0, 1]

def load_mnist_labels(filename):
    with open(filename, 'rb') as f:
        magic, num = struct.unpack('>II', f.read(8))
        labels = np.fromfile(f, dtype=np.uint8)
        return labels

# Load training and testing data
X_train = load_mnist_images(train_images_path)
y_train = load_mnist_labels(train_labels_path)
X_test = load_mnist_images(test_images_path)
y_test = load_mnist_labels(test_labels_path)

# %%
print(f"x_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"x_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# x_train: (60000, 28, 28)
# y_train: (60000,)
# x_test: (10000, 28, 28)
# y_test: (10000,)

# %%
X_train = X_train.astype('float32')  / 255.0
X_test = X_test.astype('float32')  / 255.0

# %% [markdown]
# # Create the MLP+CNN Model

# %%
X_train = X_train.reshape(-1,28,28,1)
X_test  = X_test.reshape(-1,28,28,1)

print("x_train : ",X_train.shape)
print("y_train : ",y_train.shape)
print("x_test  : ",X_test.shape)
print("y_test  : ",y_test.shape)
# Out:
# x_train :  (60000, 28, 28, 1)
# y_train :  (60000,)
# x_test  :  (10000, 28, 28, 1)
# y_test  :  (10000,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout

# Define the model
model0 = Sequential()

# Convolutional Layer
model0.add(Conv2D(filters=4, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))

# Flatten the output from the convolutional layer
model0.add(Flatten())

# Fully connected layer
model0.add(Dense(32, activation='relu'))
model0.add(Dropout(0.3))

# Output layer
model0.add(Dense(10, activation='softmax'))

# Compile the model
model0.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Summary
model0.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 4)      │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2704)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │        86,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 86,930 (339.57 KB)
#  Trainable params: 86,930 (339.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

import os

if os.path.exists("Best_points.keras"):
    os.remove("Best_points.keras")

MCP = ModelCheckpoint('Best_points.keras', verbose=1, save_best_only=True, monitor='val_accuracy', mode='max')

# %%
batch_size  = 64
epochs      = 50

start_time0 = time.time()
history0 = model0.fit(  X_train, y_train,
                      batch_size      = batch_size,
                      epochs          = epochs,
                      
                      validation_data = (X_test, y_test),callbacks=MCP)
stop_time0 = time.time()

# Calculate elapsed time
elapsed_time0 = stop_time0 - start_time0
minutes0 = int(elapsed_time0 // 60)
seconds0 = int(elapsed_time0 % 60)

# Print time used in minutes and seconds
print(f'training_time0 = {minutes0} min {seconds0} sec')
# Out:
# Epoch 1/50
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1133 - loss: 2.3019
# Epoch 1: val_accuracy improved from -inf to 0.11350, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.1133 - loss: 2.3019 - val_accuracy: 0.1135 - val_loss: 2.3009
# Epoch 2/50
# 931/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1110 - loss: 2.3014
# Epoch 2: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.1111 - loss: 2.3014 - val_accuracy: 0.1135 - val_loss: 2.3007
# Epoch 3/50
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1136 - loss: 2.3004
# Epoch 3: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.1136 - loss: 2.3004 - val_accuracy: 0.1135 - val_loss: 2.3006
# Epoch 4/50
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1091 - loss: 2.3012
# Epoch 4: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.1091 - loss: 2.3012 - val_accuracy: 0.1135 - val_loss: 2.3004
# Epoch 5/50
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1111 - loss: 2.3009
# Epoch 5: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.1112 - loss: 2.3009 - val_accuracy: 0.1135 - val_loss: 2.3003
# Epoch 6/50
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1142 - loss: 2.3003
# Epoch 6: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.1141 - loss: 2.3003 - val_accuracy: 0.1135 - val_loss: 2.3002
# Epoch 7/50
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1095 - loss: 2.3007
# Epoch 7: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.1095 - loss: 2.3007 - val_accuracy: 0.1135 - val_loss: 2.2999
# Epoch 8/50
# 931/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1112 - loss: 2.3001
# Epoch 8: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.1112 - loss: 2.3001 - val_accuracy: 0.1135 - val_loss: 2.2995
# Epoch 9/50
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1131 - loss: 2.2993
# Epoch 9: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.1131 - loss: 2.2993 - val_accuracy: 0.1135 - val_loss: 2.2992
# Epoch 10/50
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1135 - loss: 2.2995
# Epoch 10: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.1135 - loss: 2.2995 - val_accuracy: 0.1135 - val_loss: 2.2990
# Epoch 11/50
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1119 - loss: 2.2993
# Epoch 11: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.1119 - loss: 2.2993 - val_accuracy: 0.1135 - val_loss: 2.2984
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1126 - loss: 2.2987
# Epoch 12: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.1126 - loss: 2.2987 - val_accuracy: 0.1135 - val_loss: 2.2978
# Epoch 13/50
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1140 - loss: 2.2978
# Epoch 13: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.1140 - loss: 2.2978 - val_accuracy: 0.1135 - val_loss: 2.2970
# Epoch 14/50
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1161 - loss: 2.2966
# Epoch 14: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.1161 - loss: 2.2966 - val_accuracy: 0.1135 - val_loss: 2.2962
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1135 - loss: 2.2961
# Epoch 15: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.1135 - loss: 2.2961 - val_accuracy: 0.1135 - val_loss: 2.2949
# Epoch 16/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1152 - loss: 2.2949
# Epoch 16: val_accuracy improved from 0.11350 to 0.11710, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.1153 - loss: 2.2949 - val_accuracy: 0.1171 - val_loss: 2.2938
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1212 - loss: 2.2934
# Epoch 17: val_accuracy did not improve from 0.11710
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.1212 - loss: 2.2934 - val_accuracy: 0.1135 - val_loss: 2.2915
# Epoch 18/50
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1195 - loss: 2.2911
# Epoch 18: val_accuracy improved from 0.11710 to 0.12820, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.1195 - loss: 2.2911 - val_accuracy: 0.1282 - val_loss: 2.2892
# Epoch 19/50
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1359 - loss: 2.2888
# Epoch 19: val_accuracy improved from 0.12820 to 0.15110, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.1359 - loss: 2.2888 - val_accuracy: 0.1511 - val_loss: 2.2860
# Epoch 20/50
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1409 - loss: 2.2855
# Epoch 20: val_accuracy did not improve from 0.15110
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.1409 - loss: 2.2855 - val_accuracy: 0.1310 - val_loss: 2.2816
# Epoch 21/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1533 - loss: 2.2811
# Epoch 21: val_accuracy improved from 0.15110 to 0.20600, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.1534 - loss: 2.2811 - val_accuracy: 0.2060 - val_loss: 2.2760
# Epoch 22/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1621 - loss: 2.2752
# Epoch 22: val_accuracy improved from 0.20600 to 0.34730, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.1621 - loss: 2.2752 - val_accuracy: 0.3473 - val_loss: 2.2695
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2082 - loss: 2.2672
# Epoch 23: val_accuracy did not improve from 0.34730
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.2082 - loss: 2.2672 - val_accuracy: 0.1233 - val_loss: 2.2589
# Epoch 24/50
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2226 - loss: 2.2561
# Epoch 24: val_accuracy did not improve from 0.34730
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.2226 - loss: 2.2561 - val_accuracy: 0.2054 - val_loss: 2.2423
# Epoch 25/50
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2592 - loss: 2.2412
# Epoch 25: val_accuracy did not improve from 0.34730
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.2593 - loss: 2.2412 - val_accuracy: 0.3326 - val_loss: 2.2211
# Epoch 26/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2794 - loss: 2.2176
# Epoch 26: val_accuracy improved from 0.34730 to 0.42280, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.2794 - loss: 2.2176 - val_accuracy: 0.4228 - val_loss: 2.1893
# Epoch 27/50
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3279 - loss: 2.1852
# Epoch 27: val_accuracy did not improve from 0.42280
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.3279 - loss: 2.1851 - val_accuracy: 0.3830 - val_loss: 2.1414
# Epoch 28/50
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3601 - loss: 2.1361
# Epoch 28: val_accuracy did not improve from 0.42280
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.3601 - loss: 2.1360 - val_accuracy: 0.3988 - val_loss: 2.0734
# Epoch 29/50
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3927 - loss: 2.0636
# Epoch 29: val_accuracy improved from 0.42280 to 0.52190, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.3928 - loss: 2.0635 - val_accuracy: 0.5219 - val_loss: 1.9696
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4325 - loss: 1.9607
# Epoch 30: val_accuracy improved from 0.52190 to 0.58910, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.4325 - loss: 1.9607 - val_accuracy: 0.5891 - val_loss: 1.8348
# Epoch 31/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4768 - loss: 1.8345
# Epoch 31: val_accuracy improved from 0.58910 to 0.65620, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.4768 - loss: 1.8344 - val_accuracy: 0.6562 - val_loss: 1.6741
# Epoch 32/50
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5207 - loss: 1.6851
# Epoch 32: val_accuracy improved from 0.65620 to 0.70100, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.5207 - loss: 1.6848 - val_accuracy: 0.7010 - val_loss: 1.4937
# Epoch 33/50
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5596 - loss: 1.5267
# Epoch 33: val_accuracy improved from 0.70100 to 0.74000, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.5597 - loss: 1.5266 - val_accuracy: 0.7400 - val_loss: 1.3181
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5899 - loss: 1.3841
# Epoch 34: val_accuracy improved from 0.74000 to 0.75730, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.5899 - loss: 1.3840 - val_accuracy: 0.7573 - val_loss: 1.1560
# Epoch 35/50
# 936/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6304 - loss: 1.2471
# Epoch 35: val_accuracy did not improve from 0.75730
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.6304 - loss: 1.2470 - val_accuracy: 0.7534 - val_loss: 1.0614
# Epoch 36/50
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6528 - loss: 1.1444
# Epoch 36: val_accuracy improved from 0.75730 to 0.80270, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.6528 - loss: 1.1443 - val_accuracy: 0.8027 - val_loss: 0.9126
# Epoch 37/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6806 - loss: 1.0513
# Epoch 37: val_accuracy did not improve from 0.80270
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.6806 - loss: 1.0513 - val_accuracy: 0.8022 - val_loss: 0.8522
# Epoch 38/50
# 931/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6955 - loss: 0.9799
# Epoch 38: val_accuracy improved from 0.80270 to 0.82580, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.6955 - loss: 0.9797 - val_accuracy: 0.8258 - val_loss: 0.7532
# Epoch 39/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7132 - loss: 0.9199
# Epoch 39: val_accuracy improved from 0.82580 to 0.82900, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7132 - loss: 0.9198 - val_accuracy: 0.8290 - val_loss: 0.7189
# Epoch 40/50
# 936/938 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7272 - loss: 0.8727
# Epoch 40: val_accuracy improved from 0.82900 to 0.84150, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.7272 - loss: 0.8726 - val_accuracy: 0.8415 - val_loss: 0.6644
# Epoch 41/50
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7334 - loss: 0.8446
# Epoch 41: val_accuracy improved from 0.84150 to 0.85020, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7334 - loss: 0.8445 - val_accuracy: 0.8502 - val_loss: 0.6207
# Epoch 42/50
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7424 - loss: 0.8089
# Epoch 42: val_accuracy improved from 0.85020 to 0.85620, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7424 - loss: 0.8088 - val_accuracy: 0.8562 - val_loss: 0.5896
# Epoch 43/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7548 - loss: 0.7752
# Epoch 43: val_accuracy did not improve from 0.85620
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7548 - loss: 0.7752 - val_accuracy: 0.8542 - val_loss: 0.5873
# Epoch 44/50
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7617 - loss: 0.7557
# Epoch 44: val_accuracy improved from 0.85620 to 0.86450, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7617 - loss: 0.7556 - val_accuracy: 0.8645 - val_loss: 0.5489
# Epoch 45/50
# 931/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7691 - loss: 0.7280
# Epoch 45: val_accuracy improved from 0.86450 to 0.86870, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.7691 - loss: 0.7280 - val_accuracy: 0.8687 - val_loss: 0.5290
# Epoch 46/50
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7758 - loss: 0.7102
# Epoch 46: val_accuracy improved from 0.86870 to 0.87120, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.7758 - loss: 0.7102 - val_accuracy: 0.8712 - val_loss: 0.5123
# Epoch 47/50
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7800 - loss: 0.6940
# Epoch 47: val_accuracy improved from 0.87120 to 0.87130, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.7800 - loss: 0.6940 - val_accuracy: 0.8713 - val_loss: 0.5079
# Epoch 48/50
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7863 - loss: 0.6756
# Epoch 48: val_accuracy improved from 0.87130 to 0.87740, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.7864 - loss: 0.6756 - val_accuracy: 0.8774 - val_loss: 0.4828
# Epoch 49/50
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7903 - loss: 0.6662
# Epoch 49: val_accuracy improved from 0.87740 to 0.87940, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7904 - loss: 0.6662 - val_accuracy: 0.8794 - val_loss: 0.4745
# Epoch 50/50
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7988 - loss: 0.6447
# Epoch 50: val_accuracy improved from 0.87940 to 0.88190, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.7988 - loss: 0.6447 - val_accuracy: 0.8819 - val_loss: 0.4617
# training_time0 = 6 min 22 sec

# %%
from tensorflow.keras.models import load_model

# Load the best saved model
best_model = load_model('Best_points.keras')

# Evaluate the model on the test dataset
score = best_model.evaluate(X_test, y_test, verbose=0)

# Print the evaluation results
print(f'Test loss     : {score[0]:4.4f}')
print(f'Test accuracy : {score[1]:4.4f}')
# Out:
# Test loss     : 0.4617
# Test accuracy : 0.8819

# %%
plt.plot(history0.history['loss'], label='train')
plt.plot(history0.history['val_loss'], label='test')
plt.legend()

# %%
plt.plot(history0.history['accuracy'], label='train')
plt.plot(history0.history['val_accuracy'], label='test')
plt.legend()
