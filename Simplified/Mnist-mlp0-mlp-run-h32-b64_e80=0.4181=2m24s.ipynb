# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/train-images.idx3-ubyte
# /kaggle/input/t10k-labels.idx1-ubyte
# /kaggle/input/t10k-images.idx3-ubyte
# /kaggle/input/train-labels.idx1-ubyte
# /kaggle/input/t10k-labels-idx1-ubyte/t10k-labels-idx1-ubyte
# /kaggle/input/t10k-images-idx3-ubyte/t10k-images-idx3-ubyte
# /kaggle/input/train-labels-idx1-ubyte/train-labels-idx1-ubyte
# /kaggle/input/train-images-idx3-ubyte/train-images-idx3-ubyte

# %%
train_images_path = '/kaggle/input/train-images-idx3-ubyte/train-images-idx3-ubyte'
train_labels_path = '/kaggle/input/train-labels-idx1-ubyte/train-labels-idx1-ubyte'
test_images_path = '/kaggle/input/t10k-images-idx3-ubyte/t10k-images-idx3-ubyte'
test_labels_path = '/kaggle/input/t10k-labels-idx1-ubyte/t10k-labels-idx1-ubyte'

# %%
import keras
import tensorflow as tf
import time
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Add, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# %%
import numpy as np
import struct

def load_mnist_images(filename):
    with open(filename, 'rb') as f:
        magic, num, rows, cols = struct.unpack('>IIII', f.read(16))
        images = np.fromfile(f, dtype=np.uint8).reshape(num, rows, cols)
        return images / 255.0  # Normalize pixel values to [0, 1]

def load_mnist_labels(filename):
    with open(filename, 'rb') as f:
        magic, num = struct.unpack('>II', f.read(8))
        labels = np.fromfile(f, dtype=np.uint8)
        return labels

# Load training and testing data
X_train = load_mnist_images(train_images_path)
y_train = load_mnist_labels(train_labels_path)
X_test = load_mnist_images(test_images_path)
y_test = load_mnist_labels(test_labels_path)

# %%
print(f"x_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"x_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# x_train: (60000, 28, 28)
# y_train: (60000,)
# x_test: (10000, 28, 28)
# y_test: (10000,)

# %%
X_train = X_train.astype('float32')  / 255.0
X_test = X_test.astype('float32')  / 255.0

# %% [markdown]
# # Create the MLP+MLP Model

# %%
# Flatten the images from 28x28 dimensions and normalize them
X_train = X_train.reshape((X_train.shape[0], 28 * 28))
X_test = X_test.reshape((X_test.shape[0], 28 * 28))

print("x_train : ",X_train.shape)
print("y_train : ",y_train.shape)
print("x_test  : ",X_test.shape)
print("y_test  : ",y_test.shape)
# Out:
# x_train :  (60000, 784)
# y_train :  (60000,)
# x_test  :  (10000, 784)
# y_test  :  (10000,)

# %%
# Define the model
model0 = Sequential()

# Input layer
# Define the input layer with the shape corresponding to flattened 28x28 images
model0.add(tf.keras.layers.Input(shape=(28 * 28,)))

# Add the hidden layer with 32 units and ReLU activation function
model0.add(tf.keras.layers.Dense(32, activation='relu'))

# Add a dropout layer with a rate of 0.3 to reduce overfitting during training
model0.add(tf.keras.layers.Dropout(0.3))

# Add the hidden layer with 32 units and ReLU activation function
model0.add(tf.keras.layers.Dense(32, activation='relu'))

# Add a dropout layer with a rate of 0.3 to reduce overfitting during training
model0.add(tf.keras.layers.Dropout(0.3))

# Output layer: Using softmax activation for multi-class classification.
model0.add(tf.keras.layers.Dense(10, activation='softmax'))

# Compile the model
model0.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Summary
model0.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │        25,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,506 (103.54 KB)
#  Trainable params: 26,506 (103.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

import os

if os.path.exists("Best_points.keras"):
    os.remove("Best_points.keras")

MCP = ModelCheckpoint('Best_points.keras', verbose=1, save_best_only=True, monitor='val_accuracy', mode='max')

# %%
batch_size  = 64
epochs      = 80

start_time0 = time.time()
history0 = model0.fit(  X_train, y_train,
                      batch_size      = batch_size,
                      epochs          = epochs,
                      
                      validation_data = (X_test, y_test),callbacks=MCP)
stop_time0 = time.time()

# Calculate elapsed time
elapsed_time0 = stop_time0 - start_time0
minutes0 = int(elapsed_time0 // 60)
seconds0 = int(elapsed_time0 % 60)

# Print time used in minutes and seconds
print(f'training_time0 = {minutes0} min {seconds0} sec')
# Out:
# Epoch 1/80
# 929/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1181 - loss: 2.3014
# Epoch 1: val_accuracy improved from -inf to 0.11350, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1180 - loss: 2.3014 - val_accuracy: 0.1135 - val_loss: 2.3005
# Epoch 2/80
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1144 - loss: 2.3003
# Epoch 2: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1144 - loss: 2.3003 - val_accuracy: 0.1135 - val_loss: 2.3002
# Epoch 3/80
# 915/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1109 - loss: 2.3003
# Epoch 3: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1109 - loss: 2.3003 - val_accuracy: 0.1135 - val_loss: 2.3001
# Epoch 4/80
# 923/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1117 - loss: 2.3004
# Epoch 4: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1117 - loss: 2.3004 - val_accuracy: 0.1135 - val_loss: 2.2999
# Epoch 5/80
# 917/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1140 - loss: 2.3000
# Epoch 5: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1140 - loss: 2.3000 - val_accuracy: 0.1135 - val_loss: 2.2999
# Epoch 6/80
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1114 - loss: 2.3004
# Epoch 6: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1114 - loss: 2.3004 - val_accuracy: 0.1135 - val_loss: 2.2997
# Epoch 7/80
# 927/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1114 - loss: 2.3001
# Epoch 7: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1114 - loss: 2.3001 - val_accuracy: 0.1135 - val_loss: 2.2996
# Epoch 8/80
# 920/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1115 - loss: 2.3001
# Epoch 8: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1115 - loss: 2.3001 - val_accuracy: 0.1135 - val_loss: 2.2995
# Epoch 9/80
# 909/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1131 - loss: 2.2996
# Epoch 9: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1130 - loss: 2.2996 - val_accuracy: 0.1135 - val_loss: 2.2994
# Epoch 10/80
# 913/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1142 - loss: 2.2997
# Epoch 10: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1141 - loss: 2.2997 - val_accuracy: 0.1135 - val_loss: 2.2993
# Epoch 11/80
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1153 - loss: 2.2992
# Epoch 11: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1153 - loss: 2.2992 - val_accuracy: 0.1135 - val_loss: 2.2991
# Epoch 12/80
# 916/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1104 - loss: 2.2997
# Epoch 12: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1104 - loss: 2.2997 - val_accuracy: 0.1135 - val_loss: 2.2990
# Epoch 13/80
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1105 - loss: 2.2995
# Epoch 13: val_accuracy did not improve from 0.11350
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1473 - loss: 2.2818 - val_accuracy: 0.1271 - val_loss: 2.2799
# Epoch 51/80
# 920/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1605 - loss: 2.2806
# Epoch 51: val_accuracy did not improve from 0.14740
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1604 - loss: 2.2805 - val_accuracy: 0.1212 - val_loss: 2.2782
# Epoch 52/80
# 912/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1672 - loss: 2.2787
# Epoch 52: val_accuracy improved from 0.14740 to 0.18000, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1672 - loss: 2.2787 - val_accuracy: 0.1800 - val_loss: 2.2762
# Epoch 53/80
# 929/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1621 - loss: 2.2763
# Epoch 53: val_accuracy did not improve from 0.18000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1622 - loss: 2.2763 - val_accuracy: 0.1395 - val_loss: 2.2739
# Epoch 54/80
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1782 - loss: 2.2741
# Epoch 54: val_accuracy improved from 0.18000 to 0.20200, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1782 - loss: 2.2741 - val_accuracy: 0.2020 - val_loss: 2.2712
# Epoch 55/80
# 926/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1811 - loss: 2.2711
# Epoch 55: val_accuracy did not improve from 0.20200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1811 - loss: 2.2711 - val_accuracy: 0.1579 - val_loss: 2.2685
# Epoch 56/80
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1880 - loss: 2.2694
# Epoch 56: val_accuracy did not improve from 0.20200
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1880 - loss: 2.2694 - val_accuracy: 0.1910 - val_loss: 2.2653
# Epoch 57/80
# 924/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1992 - loss: 2.2654
# Epoch 57: val_accuracy improved from 0.20200 to 0.20460, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1992 - loss: 2.2654 - val_accuracy: 0.2046 - val_loss: 2.2615
# Epoch 58/80
# 930/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2055 - loss: 2.2630
# Epoch 58: val_accuracy did not improve from 0.20460
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2055 - loss: 2.2630 - val_accuracy: 0.1995 - val_loss: 2.2578
# Epoch 59/80
# 921/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2113 - loss: 2.2580
# Epoch 59: val_accuracy improved from 0.20460 to 0.21710, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2113 - loss: 2.2580 - val_accuracy: 0.2171 - val_loss: 2.2530
# Epoch 60/80
# 914/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2149 - loss: 2.2546
# Epoch 60: val_accuracy improved from 0.21710 to 0.24170, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2150 - loss: 2.2545 - val_accuracy: 0.2417 - val_loss: 2.2475
# Epoch 61/80
# 916/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2149 - loss: 2.2484
# Epoch 61: val_accuracy improved from 0.24170 to 0.27300, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2149 - loss: 2.2483 - val_accuracy: 0.2730 - val_loss: 2.2419
# Epoch 62/80
# 921/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2229 - loss: 2.2431
# Epoch 62: val_accuracy did not improve from 0.27300
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2230 - loss: 2.2430 - val_accuracy: 0.1954 - val_loss: 2.2365
# Epoch 63/80
# 908/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2267 - loss: 2.2363
# Epoch 63: val_accuracy did not improve from 0.27300
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2268 - loss: 2.2362 - val_accuracy: 0.2146 - val_loss: 2.2282
# Epoch 64/80
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2358 - loss: 2.2309
# Epoch 64: val_accuracy did not improve from 0.27300
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2358 - loss: 2.2309 - val_accuracy: 0.2508 - val_loss: 2.2185
# Epoch 65/80
# 910/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2331 - loss: 2.2208
# Epoch 65: val_accuracy did not improve from 0.27300
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2332 - loss: 2.2207 - val_accuracy: 0.2654 - val_loss: 2.2091
# Epoch 66/80
# 917/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2369 - loss: 2.2129
# Epoch 66: val_accuracy did not improve from 0.27300
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2370 - loss: 2.2128 - val_accuracy: 0.2355 - val_loss: 2.2012
# Epoch 67/80
# 930/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2438 - loss: 2.2009
# Epoch 67: val_accuracy did not improve from 0.27300
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2438 - loss: 2.2009 - val_accuracy: 0.2655 - val_loss: 2.1863
# Epoch 68/80
# 912/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2444 - loss: 2.1896
# Epoch 68: val_accuracy improved from 0.27300 to 0.29120, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2445 - loss: 2.1895 - val_accuracy: 0.2912 - val_loss: 2.1717
# Epoch 69/80
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2478 - loss: 2.1796
# Epoch 69: val_accuracy did not improve from 0.29120
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2478 - loss: 2.1796 - val_accuracy: 0.2811 - val_loss: 2.1560
# Epoch 70/80
# 911/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2516 - loss: 2.1635
# Epoch 70: val_accuracy improved from 0.29120 to 0.29980, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2516 - loss: 2.1634 - val_accuracy: 0.2998 - val_loss: 2.1406
# Epoch 71/80
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2542 - loss: 2.1532
# Epoch 71: val_accuracy did not improve from 0.29980
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2542 - loss: 2.1531 - val_accuracy: 0.2989 - val_loss: 2.1240
# Epoch 72/80
# 919/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2611 - loss: 2.1367
# Epoch 72: val_accuracy improved from 0.29980 to 0.31390, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2611 - loss: 2.1367 - val_accuracy: 0.3139 - val_loss: 2.1039
# Epoch 73/80
# 928/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2652 - loss: 2.1191
# Epoch 73: val_accuracy improved from 0.31390 to 0.34070, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2652 - loss: 2.1190 - val_accuracy: 0.3407 - val_loss: 2.0936
# Epoch 74/80
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2691 - loss: 2.1033
# Epoch 74: val_accuracy did not improve from 0.34070
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2691 - loss: 2.1033 - val_accuracy: 0.3363 - val_loss: 2.0635
# Epoch 75/80
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2697 - loss: 2.0890
# Epoch 75: val_accuracy improved from 0.34070 to 0.35550, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2697 - loss: 2.0890 - val_accuracy: 0.3555 - val_loss: 2.0440
# Epoch 76/80
# 915/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2754 - loss: 2.0731
# Epoch 76: val_accuracy did not improve from 0.35550
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2755 - loss: 2.0730 - val_accuracy: 0.3357 - val_loss: 2.0305
# Epoch 77/80
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2818 - loss: 2.0537
# Epoch 77: val_accuracy improved from 0.35550 to 0.36130, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2818 - loss: 2.0537 - val_accuracy: 0.3613 - val_loss: 2.0017
# Epoch 78/80
# 909/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2847 - loss: 2.0396
# Epoch 78: val_accuracy improved from 0.36130 to 0.38560, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2847 - loss: 2.0394 - val_accuracy: 0.3856 - val_loss: 1.9727
# Epoch 79/80
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2913 - loss: 2.0199
# Epoch 79: val_accuracy did not improve from 0.38560
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2913 - loss: 2.0199 - val_accuracy: 0.3740 - val_loss: 1.9602
# Epoch 80/80
# 913/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2957 - loss: 2.0047
# Epoch 80: val_accuracy improved from 0.38560 to 0.41810, saving model to Best_points.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2958 - loss: 2.0046 - val_accuracy: 0.4181 - val_loss: 1.9398
# training_time0 = 2 min 24 sec

# %%
from tensorflow.keras.models import load_model

# Load the best saved model
best_model = load_model('Best_points.keras')

# Evaluate the model on the test dataset
score = best_model.evaluate(X_test, y_test, verbose=0)

# Print the evaluation results
print(f'Test loss     : {score[0]:4.4f}')
print(f'Test accuracy : {score[1]:4.4f}')
# Out:
# Test loss     : 1.9398
# Test accuracy : 0.4181

# %%
plt.plot(history0.history['loss'], label='train')
plt.plot(history0.history['val_loss'], label='test')
plt.legend()

# %%
plt.plot(history0.history['accuracy'], label='train')
plt.plot(history0.history['val_accuracy'], label='test')
plt.legend()
